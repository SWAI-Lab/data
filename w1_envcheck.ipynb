# %% [markdown]
# ### 1주차 실습 - 240007 홍길동
#
# **인공지능 실무 · 2026학년도 2학기 · 소프트웨어융합과**
#
# | 학 번 | `240007` | 이 름 | `홍길동` | 실행일 | `2026-09-04` |

# %% [markdown]
# #### 1.가상환경

# %%
import os
print(os.environ["CONDA_DEFAULT_ENV"])

# %% [markdown]
# #### 2.실행 경로

# %%
import sys; print(sys.executable)

# %% [markdown]
# #### 3.Python 버전

# %%
print(sys.version)

# %% [markdown]
# #### 4.라이브러리 설치 버전

# %%
from importlib.metadata import version
for p in ("pandas", "numpy", "matplotlib", "scikit-learn", "seaborn"):
    print(p, version(p))

# %% [markdown]
# #### 5. matplotlib 렌더 + 한글 폰트

# %%
import matplotlib.pyplot as plt
plt.rcParams["font.family"] = "Malgun Gothic"
plt.rcParams["axes.unicode_minus"] = False
plt.plot([1, 2, 3], [2, 4, 3], marker="o")
plt.title("한글 제목 테스트")
plt.show()
